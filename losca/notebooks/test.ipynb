# %%
import pandas as pd

# %%
# load data
test = pd.read_excel('../../data/raw/Fases producción_test v02.xlsx')

# %%
inoculo = pd.read_csv('../../data/processed/inoculo.csv')

# %%
test
# Out:
#      LOTE  Orden en el encadenado  LOTE parental  ID Bioreactor  \
# 0   24054                       1            NaN          14616
# 1   24055                       1            NaN          14614
# 2   24056                       1            NaN          14615
# 3   24057                       1            NaN          13170
# 4   24058                       2        24055.0          14614
# 5   24059                       2        24056.0          14615
# 6   24060                       1            NaN          13169
# 7   24061                       1            NaN          14617
# 8   24062                       3        24058.0          14614
# 9   24063                       1            NaN          13170
# 10  24064                       1            NaN          14616
# 11  24065                       2        24060.0          13169
# 12  24066                       2        24061.0          14617
# 13  24067                       1            NaN          14615
# 14  24068                       3        24065.0          13169
# 15  24069                       3        24066.0          14617
# 16  24070                       1            NaN          13170
# 17  24071                       1            NaN          13170
# 18  24072                       1            NaN          14617
# 19  24073                       1            NaN          13170
# 20  24074                       1            NaN          14615
# 21  24075                       1            NaN          14614
# 22  24076                       1            NaN          14617
# 23  24077                       1            NaN          14617
# 24  24078                       1            NaN          13169
# 25  24079                       1            NaN          14615
# 26  24080                       2        24074.0          14614
# 27  24081                       2        24076.0          14617
# 28  24082                       1            NaN          13170
# 29  24083                       3        24080.0          14617
# 30  24084                       1            NaN          14614
# 31  24085                       1            NaN          14615
# 32  24086                       1            NaN          13169
# 33  24087                       2        24083.0          14614
# 34  24088                       2        24084.0          14615
# 35  24089                       1            NaN          14616
# 36  24090                       1            NaN          14617
# 37  24091                       3        24086.0          14614
# 38  24092                       1            NaN          13169
# 39  24093                       1            NaN          13170
# 40  24094                       2        24088.0          14616
# 41  24095                       2        24089.0          14617
# 42  24096                       1            NaN          14615
# 43  24097                       3        24094.0          14617
# 44  24098                       1            NaN          14616
# 45  24099                       2        24098.0          13170
# 46  24100                       3        24099.0          13170
# 47  24101                       1            NaN          13169
# 48  24103                       1            NaN          14615
# 49  24104                       1            NaN          14616
# 50  24105                       1            NaN          13170
# 51  24106                       2        24101.0          13169
# 52  24107                       2        24103.0          14615
# 53  24108                       1            NaN          14617
# 54  24109                       3        24106.0          13169
# 55  24110                       3        24107.0          14615
#
#      Fecha/hora inicio      Fecha/hora fin  Volumen de inóculo utilizado  \
# 0  2024-04-16 08:12:00 2024-04-18 07:28:00                         81.60
# 1  2024-04-13 08:18:00 2024-04-15 08:30:00                           NaN
# 2  2024-04-13 08:18:00 2024-04-15 08:15:00                           NaN
# 3  2024-04-16 08:12:00 2024-04-18 07:41:00                         82.40
# 4  2024-04-15 12:28:00 2024-04-17 08:14:00                         87.20
# 5  2024-04-15 12:27:00 2024-04-17 08:22:00                         87.20
# 6  2024-04-20 09:19:00 2024-04-22 09:12:00                         82.40
# 7  2024-04-20 09:24:00 2024-04-22 09:12:00                         81.60
# 8  2024-04-17 12:05:00 2024-04-19 08:05:00                         87.20
# 9  2024-04-23 10:35:00 2024-04-25 11:14:00                           NaN
# 10 2024-04-23 10:30:00 2024-04-25 11:10:00                           NaN
# 55 2024-07-03 12:25:00 2024-07-05 08:26:00                         80.00
#
#     Turbidez inicio cultivo  Turbidez fin cultivo  Viabilidad final cultivo  \
# 0                     15.44                 85.60                 184800000
# 1                     14.32                 73.68                 175200000
# 2                     14.56                 82.40                 168000000
# 3                     17.76                 78.96                 180800000
# 4                     18.00                 82.40                 144800000
# 5                     18.08                 78.40                 166400000
# 6                     25.92                 76.32                 161600000
# 7                     28.56                 68.96                 148800000
# 8                     18.88                 80.00                 164800000
# 9                     15.52                 68.72                 180800000
# 10                    18.56                 63.76                 174400000
# 11                    18.48                 77.60                 209600000
# 12                    19.60                 77.44                 118400000
# 13                    16.96                 76.88                 177600000
# 14                    21.20                 80.00                 173600000
# 15                    19.92                 64.40                 160000000
# 16                    16.40                 81.60                 168000000
# 17                    16.40                 81.60                 168000000
# 18                    16.16                 84.80                 195200000
# 19                    18.48                 78.40                 191200000
# 20                    18.72                 71.36                 197600000
# 21                    15.76                 76.16                 163200000
# 22                    17.12                 75.52                 179200000
# 23                    16.24                 81.60                 204800000
# 24                    18.00                 85.60                 172800000
# 25                    17.68                 75.12                 173600000
# 26                    18.72                 88.80                 124000000
# 27                    19.44                 80.00                  90400000
# 28                    18.88                 79.84                 166400000
# 29                    18.48                 85.60                 169600000
# 30                    18.32                 74.48                 180000000
# 31                    17.92                 74.96                 163200000
# 32                    16.32                 81.60                 173600000
# 33                    20.40                 74.40                 149600000
# 34                    16.72                 74.16                 171200000
# 35                    18.32                 64.80                 158400000
# 36                    18.00                 71.44                 148000000
# 37                    19.76                 73.52                 144800000
# 38                    14.00                 85.60                 195200000
# 39                    16.72                101.60                 223200000
# 40                    15.92                 73.76                 214400000
# 41                    14.24                 78.00                 204800000
# 42                    20.80                 82.40                 246400000
# 43                    33.44                101.60                 230400000
# 44                    22.24                 87.20                 240800000
# 45                    19.52                 78.48                 165600000
# 46                    20.80                 84.00                 216800000
# 47                    19.28                 92.00                 157600000
# 48                    19.04                 84.80                 172800000
# 49                    20.16                 82.40                 171200000
# 50                    19.28                 84.80                 173600000
# 51                    23.60                 84.00                 163200000
# 52                    21.76                 87.20                 151200000
# 53                    20.16                 81.60                 159200000
# 54                    23.84                 94.40                 196000000
# 55                    26.56                104.80                 157600000
#
#     ID Centrífuga  Centrifugación 1 turbidez  Centrifugación 2 turbidez  \
# 0         14246.0                      27.84                      23.96
# 1         12912.0                      30.96                      23.16
# 2         14246.0                      29.52                      28.88
# 3         12912.0                      31.04                      25.32
# 4         12912.0                      26.08                      20.36
# 5         14246.0                      26.88                      23.64
# 6         14246.0                      32.56                      17.92
# 7         12912.0                      27.76                      14.72
# 8         12912.0                      27.52                      24.64
# 9         12912.0                      25.92                      18.28
# 10        14246.0                      29.36                      12.48
# 11        14246.0                      29.28                      25.16
# 12        12912.0                      27.44                      21.44
# 13        17825.0                      32.16                      18.20
# 14        14246.0                      30.00                      22.24
# 15        12912.0                      31.76                      25.36
# 16        14246.0                      30.00                      22.52
# 17        14246.0                      30.00                      22.52
# 18        12912.0                      30.48                      22.36
# 19        14246.0                      31.92                      19.28
# 20        17825.0                      34.40                      22.28
# 21        14246.0                      26.56                      19.44
# 22        12912.0                      29.68                      18.72
# 23        12912.0                      29.60                      24.56
# 24        17825.0                      33.92                      26.20
# 25        14246.0                      29.36                      20.88
# 26        14246.0                      28.72                      24.16
# 27        17825.0                      29.44                      21.24
# 28        14246.0                      29.84                      18.20
# 29        14246.0                      27.20                      23.52
# 30        17825.0                      30.24                      17.20
# 31        14246.0                      27.92                      16.92
# 32        17825.0                      30.80                      23.80
# 33        12912.0                      27.60                      18.84
# 34        14246.0                      25.20                      18.64
# 35        12912.0                      26.88                      13.24
# 36        14246.0                      27.68                      15.00
# 37        12912.0                      26.08                      19.56
# 38        12912.0                      30.48                      27.76
# 39        17825.0                      38.80                      39.04
# 40        12912.0                      23.76                      22.12
# 41        14246.0                      22.32                      19.72
# 42        17825.0                      42.32                      35.28
# 43        14246.0                      33.92                      31.40
# 44        12912.0                      37.12                      18.84
# 45        12912.0                      29.60                      18.60
# 46        12912.0                      32.80                      24.64
# 47        12912.0                      31.84                      23.48
# 48        14246.0                      29.44                      19.76
# 49        14246.0                      30.80                      20.56
# 50        17825.0                      31.84                      19.16
# 51        12912.0                      32.40                      26.40
# 52        14246.0                      28.32                      23.28
# 53        14246.0                      29.92                      15.40
# 54        12912.0                      31.84                      28.68
# 55        14246.0                      34.40                      27.80
#
#     Producto 1  Producto 2
# 0          NaN         NaN
# 1          NaN         NaN
# 2          NaN         NaN
# 3          NaN         NaN
# 4          NaN         NaN
# 5          NaN         NaN
# 6          NaN         NaN
# 7          NaN         NaN
# 8          NaN         NaN
# 9          NaN         NaN
# 10         NaN         NaN
# 11         NaN         NaN
# 12         NaN         NaN
# 13         NaN         NaN
# 14         NaN         NaN
# 15         NaN         NaN
# 16         NaN         NaN
# 17         NaN         NaN
# 18         NaN         NaN
# 19         NaN         NaN
# 20         NaN         NaN
# 21         NaN         NaN
# 22         NaN         NaN
# 23         NaN         NaN
# 24         NaN         NaN
# 25         NaN         NaN
# 26         NaN         NaN
# 27         NaN         NaN
# 28         NaN         NaN
# 29         NaN         NaN
# 30         NaN         NaN
# 31         NaN         NaN
# 32         NaN         NaN
# 33         NaN         NaN
# 34         NaN         NaN
# 35         NaN         NaN
# 36         NaN         NaN
# 37         NaN         NaN
# 38         NaN         NaN
# 39         NaN         NaN
# 40         NaN         NaN
# 41         NaN         NaN
# 42         NaN         NaN
# 43         NaN         NaN
# 44         NaN         NaN
# 45         NaN         NaN
# 46         NaN         NaN
# 47         NaN         NaN
# 48         NaN         NaN
# 49         NaN         NaN
# 50         NaN         NaN
# 51         NaN         NaN
# 52         NaN         NaN
# 53         NaN         NaN
# 54         NaN         NaN
# 55         NaN         NaN

# %%
test['LOTE'] = test['LOTE'].astype(str)

# %%
# Inoculo unique vs test unique
inoculo_unique = inoculo['LOTE'].unique()
test_unique = test['LOTE'].unique()
# perform intersection
intersection = list(set(inoculo_unique) & set(test_unique))

# %%
# Load pino_rebuilt
pino_rebuilt = pd.read_csv('../../data/processed/pino_rebuilt.csv')
pino_rebuilt.info()
pino_rebuilt['Lote'] = pino_rebuilt['Lote'].astype(str)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 302 entries, 0 to 301
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ph          302 non-null    float64
#  1   turb        302 non-null    float64
#  2   f_h_inicio  302 non-null    object
#  3   f_h_fin     302 non-null    object
#  4   duracion    302 non-null    object
#  5   Lote        302 non-null    object
# dtypes: float64(2), object(4)
# memory usage: 14.3+ KB

# %%
# Are there LOTE which are not in the pino data? get the number of them
pino_rebuilt['Lote'].isin(test['LOTE']).value_counts()
# Reverse
test['LOTE'].isin(pino_rebuilt['Lote']).value_counts()
# Out:
# LOTE
# True     33
# False    23
# Name: count, dtype: int64

# %%
# load OF
OF = pd.read_csv('../../data/processed/OF.csv')
OF['Lote'] = OF['Lote'].astype(str)
OF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207 entries, 0 to 206
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Orden               207 non-null    int64
#  1   Lote                207 non-null    object
#  2   Cantidad entregada  207 non-null    float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 5.0+ KB

# %%
# Are there LOTE which are not in the OF data? get the number of them
OF['Lote'].isin(test['LOTE']).value_counts()
# Reverse
test['LOTE'].isin(OF['Lote']).value_counts()
# Out:
# LOTE
# True     55
# False     1
# Name: count, dtype: int64

# %%
# Load mov_componentes
mov_componentes = pd.read_csv('../../data/processed/mov_componentes.csv')
mov_componentes['Lote'] = mov_componentes['Lote'].astype(str)
mov_componentes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4920 entries, 0 to 4919
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Lote             4920 non-null   object
#  1   Material         4920 non-null   int64
#  2   Lote interno     4920 non-null   int64
#  3   Lote Proveedor   4920 non-null   object
#  4   Qty              4920 non-null   float64
#  5   Fecha recepción  4920 non-null   object
#  6   Fecha traslado   4920 non-null   object
#  7   Duration         4920 non-null   object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 307.6+ KB

# %%
# Are there LOTE which are not in the mov_componentes data? get the number of them
#use apply
mov_componentes['Lote'].isin(test['LOTE'])
# Reverse
test['LOTE'].isin(mov_componentes['Lote']).value_counts()
# Out:
# LOTE
# True     54
# False     2
# Name: count, dtype: int64

# %%
# lote which is not in any of the data
# Not in mov_componentes
notmov = test[~test['LOTE'].isin(mov_componentes['Lote'])]
# Not in OF
notof = test[~test['LOTE'].isin(OF['Lote'])]
# Not in pino_rebuilt
not_pino = test[~test['LOTE'].isin(pino_rebuilt['Lote'])]

# 24076

# %%
# Extract with lote = 24076, f_h_inicio from pino
pino_rebuilt[pino_rebuilt['Lote'] == '24076']
# Out:
#         ph   turb           f_h_inicio              f_h_fin         duracion  \
# 111  5.408  27.36  2024-05-16 00:30:00  2024-05-17 07:15:00  1 days 06:45:00
# 231  5.408  28.08  2024-05-16 00:30:00  2024-05-17 07:15:00  1 days 06:45:00
#
#       Lote
# 111  24076
# 231  24076

# %%
# load cultivo.csv
cultivo = pd.read_csv('../../data/processed/cultivo.csv')
cultivo.info()
cultivo['LOTE'] = cultivo['LOTE'].astype(str)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 152 entries, 0 to 151
# Data columns (total 17 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   LOTE                          152 non-null    int64
#  1   Orden en el encadenado        152 non-null    int64
#  2   LOTE parental                 22 non-null     float64
#  3   ID Bioreactor                 152 non-null    int64
#  4   Fecha/hora inicio             152 non-null    object
#  5   Fecha/hora fin                152 non-null    object
#  6   Volumen de inóculo utilizado  147 non-null    float64
#  7   Turbidez inicio cultivo       152 non-null    float64
#  8   Turbidez fin cultivo          152 non-null    float64
#  9   Viabilidad final cultivo      152 non-null    float64
#  10  ID Centrífuga                 152 non-null    int64
#  11  Centrifugación 1 turbidez     148 non-null    float64
#  12  Centrifugación 2 turbidez     143 non-null    float64
#  13  Producto 1                    152 non-null    float64
#  14  Producto 2                    152 non-null    float64
#  15  Duracion                      152 non-null    object
#  16  turbidez_diff                 152 non-null    float64
# dtypes: float64(10), int64(4), object(3)
# memory usage: 20.3+ KB

# %%
# is there any Fecha/hora inicio > f_h_inicio from pino_rebuilt?
# Merge
cultivo_pino = pd.merge(cultivo, pino_rebuilt, left_on='LOTE', right_on='Lote')
cultivo_pino['Fecha/hora inicio'] = pd.to_datetime(cultivo_pino['Fecha/hora inicio'])
cultivo_pino['f_h_inicio'] = pd.to_datetime(cultivo_pino['f_h_inicio'])
# Show the rows where Fecha/hora inicio > f_h_inicio
cultivo_pino[cultivo_pino['Fecha/hora inicio'] < cultivo_pino['f_h_inicio']]
# Out:
# Empty DataFrame
# Columns: [LOTE, Orden en el encadenado, LOTE parental, ID Bioreactor, Fecha/hora inicio, Fecha/hora fin, Volumen de inóculo utilizado, Turbidez inicio cultivo, Turbidez fin cultivo, Viabilidad final cultivo, ID Centrífuga, Centrifugación 1 turbidez, Centrifugación 2 turbidez, Producto 1, Producto 2, Duracion, turbidez_diff, ph, turb, f_h_inicio, f_h_fin, duracion, Lote]
# Index: []
#
# [0 rows x 23 columns]

# %%
cultivo_pino[cultivo_pino['Fecha/hora inicio'] < cultivo_pino['f_h_inicio']]['LOTE'].nunique()
# Out:
# 0

# %%
cultivo_pino[cultivo_pino['Fecha/hora inicio'] > cultivo_pino['f_h_inicio']]['LOTE'].nunique()
# Out:
# 118

# %%
# Get the number of lotes from pino which are not in the cultivo data
pino_rebuilt['Lote'].isin(cultivo['LOTE']).value_counts()
## Reverse
cultivo['LOTE'].isin(pino_rebuilt['Lote']).value_counts()
# Out:
# LOTE
# True     118
# False     34
# Name: count, dtype: int64

# %%
# And in test?
test_pino = pd.merge(test, pino_rebuilt, left_on='LOTE', right_on='Lote')
test_pino['Fecha/hora inicio'] = pd.to_datetime(test_pino['Fecha/hora inicio'])
test_pino['f_h_inicio'] = pd.to_datetime(test_pino['f_h_inicio'])
# Show the rows where Fecha/hora inicio > f_h_inicio
# drop dupes
test_pino = test_pino.drop_duplicates()
test_pino[test_pino['Fecha/hora inicio'] < test_pino['f_h_inicio']]
# Group that by LOTE
#test_pino[test_pino['Fecha/hora inicio'] < test_pino['f_h_inicio']].groupby('LOTE').size().index.nunique()
# Out:
#      LOTE  Orden en el encadenado  LOTE parental  ID Bioreactor  \
# 20  24071                       1            NaN          13170
# 21  24072                       1            NaN          14617
# 24  24074                       1            NaN          14615
# 25  24074                       1            NaN          14615
# 26  24076                       1            NaN          14617
# 27  24076                       1            NaN          14617
# 25  1 days 06:45:00  24074
# 26  1 days 06:45:00  24076
# 27  1 days 06:45:00  24076
# 28  1 days 06:44:00  24077
# 29  1 days 06:44:00  24077
# 32  1 days 07:35:00  24081
# 33  1 days 07:35:00  24081
# 34  1 days 06:56:00  24083
# 35  1 days 06:56:00  24083
# 38  1 days 07:35:00  24085
# 39  1 days 07:35:00  24085
# 40  1 days 07:16:00  24088
# 41  1 days 07:16:00  24088
# 44  1 days 06:33:00  24091
# 45  1 days 06:33:00  24091
# 48  1 days 06:39:00  24095
# 49  1 days 06:39:00  24095
# 50  1 days 06:39:00  24097
# 51  1 days 06:39:00  24097
#
# [22 rows x 21 columns]

# %%
test_pino[test_pino['Fecha/hora inicio'] > test_pino['f_h_inicio']]
# Group taht by LOTE
test_pino[test_pino['Fecha/hora inicio'] > test_pino['f_h_inicio']].groupby('LOTE').size().index.nunique()
# Out:
# 21

# %%
test_pino['LOTE'].nunique()
# Out:
# 33

# %%
test['LOTE'].nunique()
# Out:
# 56

# %%
test.shape
# Out:
# (56, 15)

# %%
# Now with ino, load ino with pkl
ino = pd.read_pickle('../../data/processed/inoculo.pkl')
ino.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 161 entries, 4 to 166
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   lote                  161 non-null    object
#  1   id_bio                161 non-null    int64
#  2   f_h_inicio_ino        161 non-null    object
#  3   f_h_fin_ino           161 non-null    object
#  4   vol_cultivo_ino       161 non-null    float64
#  5   turb_inicio_cultivo   161 non-null    float64
#  6   turb_fin_cultivo      161 non-null    float64
#  7   viab_fin_cultivo_ino  161 non-null    float64
#  8   turb_diff_ino         161 non-null    float64
#  9   dur_ino               161 non-null    object
# dtypes: float64(5), int64(1), object(4)
# memory usage: 13.8+ KB

# %%
# f_h_inicio to datetime
ino['f_h_inicio_ino'] = pd.to_datetime(ino['f_h_inicio_ino'])
# f_h_fin to datetime
ino['f_h_fin_ino'] = pd.to_datetime(ino['f_h_fin_ino'])
ino.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 161 entries, 4 to 166
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   lote                  161 non-null    object
#  1   id_bio                161 non-null    int64
#  2   f_h_inicio_ino        161 non-null    datetime64[ns]
#  3   f_h_fin_ino           161 non-null    datetime64[ns]
#  4   vol_cultivo_ino       161 non-null    float64
#  5   turb_inicio_cultivo   161 non-null    float64
#  6   turb_fin_cultivo      161 non-null    float64
#  7   viab_fin_cultivo_ino  161 non-null    float64
#  8   turb_diff_ino         161 non-null    float64
#  9   dur_ino               161 non-null    object
# dtypes: datetime64[ns](2), float64(5), int64(1), object(2)
# memory usage: 13.8+ KB

# %%
# Now merge ino with test
test_ino = pd.merge(test, ino, left_on='LOTE', right_on='lote')
test_ino['Fecha/hora inicio'] = pd.to_datetime(test_ino['Fecha/hora inicio'])
test_ino['f_h_inicio_ino'] = pd.to_datetime(test_ino['f_h_inicio_ino'])
# Show the rows where Fecha/hora inicio > f_h_inicio
test_ino[test_ino['Fecha/hora inicio'] < test_ino['f_h_inicio_ino']]
# Out:
#      LOTE  Orden en el encadenado  LOTE parental  ID Bioreactor  \
# 10  24071                       1            NaN          13170
# 11  24072                       1            NaN          14617
# 13  24074                       1            NaN          14615
# 19          166.240               14.08             26.32
# 21          161.200               16.24             25.52
# 22          166.800               16.00             25.52
# 24          166.800               17.20             25.60
# 26          168.240               12.08             21.44
# 27          168.240               12.08             21.44
#
#    viab_fin_cultivo_ino turb_diff_ino          dur_ino
# 10           84000000.0          9.52  1 days 01:45:00
# 11          144800000.0         11.28  1 days 00:17:00
# 13          129600000.0          9.60  1 days 00:53:00
# 15          129600000.0          9.60  1 days 00:53:00
# 16          122400000.0         10.24  0 days 23:47:00
# 18          122400000.0          9.28  0 days 23:49:00
# 19          124800000.0         12.24  1 days 01:29:00
# 21          122400000.0          9.28  0 days 23:49:00
# 22          129600000.0          9.52  1 days 00:10:00
# 24          104000000.0          8.40  1 days 00:00:00
# 26           83200000.0          9.36  1 days 00:25:00
# 27           83200000.0          9.36  1 days 00:25:00
#
# [12 rows x 25 columns]

# %%
# Get unique
test_ino[test_ino['Fecha/hora inicio'] < test_ino['f_h_inicio_ino']]['LOTE'].nunique()
# Out:
# 12

# %%
# load of with pkl
of = pd.read_pickle('../../data/processed/of.pkl')

# %%
# Is there any of those 12 in the OF data?
twelve = test_ino[test_ino['Fecha/hora inicio'] < test_ino['f_h_inicio_ino']]['LOTE'].unique()
# is any of those 12 in the OF data?
of['lote'].apply(lambda x: x in twelve).value_counts()
# print them
of[of['lote'].apply(lambda x: x in twelve)]
# Out:
#          orden   lote  cantidad_of
# 142  200200230  24074        13.38
# 172  200202555  24071        13.57
# 173  200202557  24072        13.72
# 177  200205524  24091        13.71
# 179  200205527  24077        13.72
# 182  200205530  24083        13.75
# 183  200205531  24085        13.77
# 185  200205533  24081        13.72
# 187  200205535  24088        13.67
# 193  200205684  24095        13.65
# 194  200205685  24097        13.73

# %%
# Are those lotes the same as before?
unique_pino = test_pino[test_pino['Fecha/hora inicio'] < test_pino['f_h_inicio']]['LOTE'].unique()
unique_ino = test_ino[test_ino['Fecha/hora inicio'] < test_ino['f_h_inicio']]['LOTE'].unique()

# Compare the sets
set(unique_pino) == set(unique_ino)
# Out:
# True

# %%
# Does this happen with cultivo?
cultivo_ino = pd.merge(cultivo, ino, left_on='LOTE', right_on='lote')
cultivo_ino['Fecha/hora inicio'] = pd.to_datetime(cultivo_ino['Fecha/hora inicio'])
cultivo_ino['f_h_inicio'] = pd.to_datetime(cultivo_ino['f_h_inicio'])
# Show the rows where Fecha/hora inicio > f_h_inicio
cultivo_ino[cultivo_ino['Fecha/hora inicio'] < cultivo_ino['f_h_inicio']]
# Out:
# Empty DataFrame
# Columns: [LOTE, Orden en el encadenado, LOTE parental, ID Bioreactor, Fecha/hora inicio, Fecha/hora fin, Volumen de inóculo utilizado, Turbidez inicio cultivo, Turbidez fin cultivo, Viabilidad final cultivo, ID Centrífuga, Centrifugación 1 turbidez, Centrifugación 2 turbidez, Producto 1, Producto 2, Duracion, lote, id_bio, f_h_inicio, f_h_fin, volumen_cultivo, turbidez_inicio_cultivo, turbidez_fin_cultivo, viabilidad_fin_cultivo, turbidez_diff, duracion_cultivo]
# Index: []
#
# [0 rows x 26 columns]
